# %% [markdown]
# # BART Capstone Project

# %% [markdown]
# ### Analysing ridership data collected over a decade long period to predict seat availability on the BART using regression models.The Bay Area Rapid Trasit has over 800,000 daily passengers, and is the fifth biggest public transportation system in the country. A big slice of the ridership tends to commuting residents during rush hour, when trains can contain over 5000 passengers.  This causes overcrowding in cars and hence a metric to predict seat availablity can help riders decide between their time of travel or convinience of a seat.
#
# ### Using these metrics we can provide further insight into traffic along routes and population denisty. Understanding those trends are key to be able to provide advise on future expansion plans for the BART infrastructure and its subsidiaries.

# %% [markdown]
# #### Import files

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from IPython.display import Image

p='./'

# %% [markdown]
# #### Loading RTGS information through format recieved online

# %%
stops =            pd.read_csv(p+'datasets/bart/stops.txt')
agency =           pd.read_csv(p+'datasets/bart/agency.txt')
calendar =         pd.read_csv(p+'datasets/bart/calendar.txt')
calendar_dates =   pd.read_csv(p+'datasets/bart/calendar_dates.txt')
fare_attributes =  pd.read_csv(p+'datasets/bart/fare_attributes.txt')
fare_rules =       pd.read_csv(p+'datasets/bart/fare_rules.txt')
feed_info =        pd.read_csv(p+'datasets/bart/feed_info.txt')
frequencies =      pd.read_csv(p+'datasets/bart/frequencies.txt')
routes =           pd.read_csv(p+'datasets/bart/routes.txt')
shapes =           pd.read_csv(p+'datasets/bart/shapes.txt')
stop_times =       pd.read_csv(p+'datasets/bart/stop_times.txt')
transfers =        pd.read_csv(p+'datasets/bart/transfers.txt')
trips =            pd.read_csv(p+'datasets/bart/trips.txt');

# %% [markdown]
# ### BART system Map

# %%
bartmap = Image(filename=p+'datasets/bart/system-map.gif')

# %%
bartmap

# %% [markdown]
# ##### List of BART stations currently operational

# %%
stops['stop_name']
# Out:
# 0            12th St. Oakland City Center BART Station
# 1                        16th St. Mission BART Station
# 2                        19th St. Oakland BART Station
# 3                        24th St. Mission BART Station
# 4                                 Antioch BART Station
# 5                                   Ashby BART Station
# 6                             Balboa Park BART Station
# 7                                Bay Fair BART Station
# 8                           Castro Valley BART Station
# 9                   Civic Center/UN Plaza BART Station
# 10                               Coliseum BART Station
# 11                                  Colma BART Station
# 12                                Concord BART Station
# 13                              Daly City BART Station
# 14                      Downtown Berkeley BART Station
# 15                      Dublin/Pleasanton BART Station
# 16                   El Cerrito del Norte BART Station
# 17                       El Cerrito Plaza BART Station
# 18                            Embarcadero BART Station
# 19                                Fremont BART Station
# 20                              Fruitvale BART Station
# 21                              Glen Park BART Station
# 22                                Hayward BART Station
# 23                              Lafayette BART Station
# 24                           Lake Merritt BART Station
# 25                              MacArthur BART Station
# 26                               Millbrae BART Station
# 27                         Montgomery St. BART Station
# 28                         North Berkeley BART Station
# 29                 North Concord/Martinez BART Station
# 30          Oakland International Airport BART Station
# 31                                 Orinda BART Station
# 32                    Pittsburg/Bay Point BART Station
# 33                       Pittsburg Center BART Station
# 34      Pleasant Hill/Contra Costa Centre BART Station
# 35                             Powell St. BART Station
# 36                               Richmond BART Station
# 37                              Rockridge BART Station
# 38                              San Bruno BART Station
# 39    San Francisco International Airport BART Station
# 40                            San Leandro BART Station
# 41                          South Hayward BART Station
# 42                    South San Francisco BART Station
# 43                             Union City BART Station
# 44                           Walnut Creek BART Station
# 45             Warm Springs/South Fremont BART Station
# 46                 West Dublin/Pleasanton BART Station
# 47                           West Oakland BART Station
# Name: stop_name, dtype: object

# %%
stops.head()
# Out:
#   stop_id                                  stop_name  stop_desc   stop_lat  \
# 0    12TH  12th St. Oakland City Center BART Station        NaN  37.803768
# 1    16TH              16th St. Mission BART Station        NaN  37.765062
# 2    19TH              19th St. Oakland BART Station        NaN  37.808350
# 3    24TH              24th St. Mission BART Station        NaN  37.752470
# 4    ANTC                       Antioch BART Station        NaN  37.995388
#
#      stop_lon zone_id                            stop_url  location_type  \
# 0 -122.271450    12TH  http://www.bart.gov/stations/12TH/              0
# 1 -122.419694    16TH  http://www.bart.gov/stations/16TH/              0
# 2 -122.268602    19TH  http://www.bart.gov/stations/19TH/              0
# 3 -122.418143    24TH  http://www.bart.gov/stations/24TH/              0
# 4 -121.780420    ANTC  http://www.bart.gov/stations/ANTC/              0
#
#    parent_station  stop_timezone  wheelchair_boarding
# 0             NaN            NaN                    1
# 1             NaN            NaN                    1
# 2             NaN            NaN                    1
# 3             NaN            NaN                    1
# 4             NaN            NaN                    1

# %%
agency.head()
# Out:
#   agency_id             agency_name           agency_url      agency_timezone  \
# 0      BART  Bay Area Rapid Transit  http://www.bart.gov  America/Los_Angeles
#
#   agency_lang
# 0          en

# %%
calendar.head()
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0       WKDY       1        1          1         1       1         0       0
# 1        SAT       0        0          0         0       0         1       0
# 2        SUN       0        0          0         0       0         0       1
#
#    start_date  end_date
# 0    20180910  20190910
# 1    20180910  20190910
# 2    20180910  20190910

# %%
calendar_dates
# Out:
#   service_id      date  exception_type
# 0        SUN  20181122               1
# 1       WKDY  20181122               2
# 2        SUN  20181225               1
# 3       WKDY  20181225               2
# 4        SUN  20190101               1
# 5       WKDY  20190101               2
# 6        SAT  20190121               1
# 7       WKDY  20190121               2
# 8        SUN  20190218               1
# 9       WKDY  20190218               2

# %%
fare_rules.head()
# Out:
#    fare_id  route_id origin_id destination_id  contains_id
# 0      128       NaN      SSAN           SSAN          NaN
# 1       76       NaN      SSAN           SBRN          NaN
# 2      167       NaN      SSAN           SFIA          NaN
# 3       76       NaN      SSAN           MLBR          NaN
# 4      145       NaN      SSAN           WDUB          NaN

# %%
fare_attributes.head()
# Out:
#    fare_id  price currency_type  payment_method  transfers  transfer_duration
# 0       50   2.50           USD               1        NaN                NaN
# 1       51   2.55           USD               1        NaN                NaN
# 2       52   2.60           USD               1        NaN                NaN
# 3       53   2.65           USD               1        NaN                NaN
# 4       54   2.70           USD               1        NaN                NaN

# %%
plt.figure(figsize=(12,8))
plt.plot(fare_attributes['price'])
plt.xlabel('Routes')
plt.ylabel('Fare in $')
plt.title('FARE for BART Routes')
# Out:
# Text(0.5,1,'FARE for BART Routes')

# %% [markdown]
# As we can see above, as the distance between routes increases, so does the fare proportionaly. However for the longest routes, we can see a sharp uptick. This is to compensate for the increased distance in the end of the lines. One of these routes is the WARM SPRINGS-DALY CITY line, encompossing over 50 miles of track, and hence the high price

# %%
feed_info.head()
# Out:
#       feed_publisher_name   feed_publisher_url feed_lang  feed_start_date  \
# 0  Bay Area Rapid Transit  http://www.bart.gov        en         20180910
#
#    feed_end_date  feed_version
# 0       20190910            48

# %%
frequencies.head()
# Out:
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, headway_secs]
# Index: []

# %%
routes
# Out:
#    route_id agency_id  route_short_name  \
# 0         1      BART               NaN
# 1         3      BART               NaN
# 2         5      BART               NaN
# 3         7      BART               NaN
# 4        11      BART               NaN
# 5        19      BART               NaN
#
#                           route_long_name  route_desc  route_type  \
# 0                 Antioch - SFIA/Millbrae         NaN           1
# 1   Warm Springs/South Fremont - Richmond         NaN           1
# 2  Warm Springs/South Fremont - Daly City         NaN           1
# 3           Richmond - Daly City/Millbrae         NaN           1
# 4           Dublin/Pleasanton - Daly City         NaN           1
# 5              Oakland Airport - Coliseum         NaN           1
#
#                                            route_url route_color  \
# 0  http://www.bart.gov/schedules/bylineresults?ro...      ffff33
# 1  http://www.bart.gov/schedules/bylineresults?ro...      ff9933
# 2  http://www.bart.gov/schedules/bylineresults?ro...      339933
# 3  http://www.bart.gov/schedules/bylineresults?ro...      ff0000
# 4  http://www.bart.gov/schedules/bylineresults?ro...      0099cc
# 5  http://www.bart.gov/schedules/bylineresults?ro...      d5cfa3
#
#    route_text_color
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN

# %%
shapes.head()
# Out:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0   01_shp     38.018937   -121.942073                  0
# 1   01_shp     38.018920   -121.942449                  1
# 2   01_shp     38.018917   -121.942633                  2
# 3   01_shp     38.018919   -121.942820                  3
# 4   01_shp     38.018915   -121.943121                  4

# %%
stop_times.head()
# Out:
#       trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0  3650800SUN     08:00:00       08:00:00    LAFY              1
# 1  3650800SUN     08:05:00       08:05:00    ORIN              2
# 2  3650800SUN     08:11:00       08:11:00    ROCK              3
# 3  3650800SUN     08:15:00       08:15:00    MCAR              4
# 4  3650800SUN     08:18:00       08:18:00    19TH              5
#
#   stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  timepoint
# 0      Millbrae          NaN            NaN                  NaN          1
# 1      Millbrae          NaN            NaN                  NaN          1
# 2      Millbrae          NaN            NaN                  NaN          1
# 3      Millbrae          NaN            NaN                  NaN          1
# 4      Millbrae          NaN            NaN                  NaN          1

# %%
plt.plot(stop_times['stop_headsign'])

# %%
plt.plot(trips['trip_headsign'])

# %% [markdown]
# ### EDA for ridership report that I got from BART.gov

# %% [markdown]
# #### 2014 Weekday Ridership

# %%
jan2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_January2014.xlsx')
feb2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_February2014.xlsx')
march2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_March2014.xlsx')
april2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_April2014.xlsx')
may2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_May2014.xlsx')
june2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_June2014.xlsx')
july2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_July2014.xlsx')
aug2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_August2014.xlsx')
sept2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_September2014.xlsx')
oct2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_October2014.xlsx')
nov2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_November2014.xlsx')
dec2014= pd.read_excel(p+'datasets/bart/ridership/Ridership_December2014.xlsx')

# %% [markdown]
# #### 2015 Weekday Ridership

# %%
jan2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_January2015.xlsx')
feb2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_February2015.xlsx')
march2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_March2015.xlsx')
april2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_April2015.xlsx')
may2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_May2015.xlsx')
june2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_June2015.xlsx')
july2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_July2015.xlsx')
aug2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_August2015.xlsx')
sept2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_September2015.xlsx')
oct2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_October2015.xlsx')
nov2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_November2015.xlsx')
dec2015= pd.read_excel(p+'datasets/bart/ridership/Ridership_December2015.xlsx')

# %% [markdown]
# #### 2016 Weekday Ridership

# %%
jan2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_January2016.xlsx')
feb2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_February2016.xlsx')
march2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_March2016.xlsx')
april2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_April2016.xlsx')
may2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_May2016.xlsx')
june2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_June2016.xlsx')
july2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_July2016.xlsx')
aug2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_August2016.xlsx')
sept2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_September2016.xlsx')
oct2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_October2016.xlsx')
nov2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_November2016.xlsx')
dec2016= pd.read_excel(p+'datasets/bart/ridership/Ridership_December2016.xlsx')

# %% [markdown]
# #### 2017 Weekday Ridership

# %%
jan2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_January2017.xlsx')
feb2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_February2017.xlsx')
march2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_March2017.xlsx')
april2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_April2017.xlsx')
may2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_May2017.xlsx')
june2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_June2017.xlsx')
july2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_July2017.xlsx')
aug2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_August2017.xlsx')
sept2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_September2017.xlsx')
oct2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_October2017.xlsx')
nov2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_November2017.xlsx')
dec2017= pd.read_excel(p+'datasets/bart/ridership/Ridership_December2017.xlsx')

# %% [markdown]
# #### Function to format dataframes

# %%
def createdatanew(df):
    df.columns = df.iloc[0]
    df = df[1:]
    df = df.iloc[:,:48]
    df.columns.values[0] = 'Station'
    df.set_index('Station',inplace=True)
    return df

# %%
def createdata(df):
    df.columns = df.iloc[0]
    df = df[1:]
    df.columns.values[0] = 'Station'
    df.set_index('Station',inplace=True)
    return df

# %% [markdown]
# What one typical dataframe looks like. It is correlated between all the BART stations accounting for a 47x47 Dataframe including Entry and Exit Totals. In this scenario it is for weekdays in December of 2017

# %%
jan2015 = createdatanew(jan2015)
feb2015 = createdatanew(feb2015)
march2015 = createdatanew(march2015)
april2015 = createdatanew(april2015)
may2015 = createdatanew(may2015)
june2015 = createdatanew(june2015)
july2015 = createdatanew(july2015)
aug2015 = createdatanew(aug2015)
sept2015 = createdatanew(sept2015)
oct2015 = createdatanew(oct2015)
nov2015 = createdatanew(nov2015)
dec2015 = createdatanew(dec2015)

# %%
jan2016 = createdatanew(jan2016)
feb2016 = createdata(feb2016)
march2016 = createdata(march2016)
april2016 = createdata(april2016)
may2016 = createdata(may2016)
june2016 = createdata(june2016)
july2016 = createdata(july2016)
aug2016 = createdata(aug2016)
sept2016 = createdata(sept2016)
oct2016 = createdata(oct2016)
nov2016 = createdata(nov2016)
dec2016 = createdata(dec2016)

# %%
jan2017 = createdata(jan2017)
feb2017 = createdata(feb2017)
march2017 = createdata(march2017)
april2017 = createdata(april2017)
may2017 = createdata(may2017)
june2017 = createdata(june2017)
july2017 = createdata(july2017)
aug2017 = createdata(aug2017)
sept2017 = createdata(sept2017)
oct2017 = createdata(oct2017)
nov2017 = createdata(nov2017)
dec2017 = createdata(dec2017)

# %% [markdown]
# #### List of months

# %%
list_of_months=[jan2015,feb2015,march2015,april2015,may2015,june2015,july2015,aug2015,sept2015,oct2015,
              nov2015,dec2015,jan2016,feb2016,march2016,april2016,may2016,june2016,july2016,aug2016,sept2016,oct2016,
              nov2016,dec2016,jan2017,feb2017,march2017,april2017,may2017,june2017,july2017,aug2017,sept2017,oct2017,
              nov2017,dec2017]

# %% [markdown]
# NOTE : Creating a function to be able to see the values between any 2 station for the last 36 months. By having these values we can condense 36 dataframes into one to find the mean or see a cluster of individual routes.

# %%
def value(entry, exit):
    values = []
    for i in range(len(list_of_months)):
        values.append(list_of_months[i][entry][exit])
    return values

# %% [markdown]
# Ridership from Montogomery Street Station to the Fremont Station for the past 36 months

# %%
value('MT','FM')
# Out:
# [1529.1052631578948,
#  1599.4736842105262,
#  1559.7727272727273,
#  1570.7727272727273,
#  1559.6,
#  1643.5,
#  1638.8636363636363,
#  1679.4285714285713,
#  1724.2380952380952,
#  1714.5714285714287,
#  1686.3333333333333,
#  1518.45,
#  1686.3684210526317,
#  1761.05,
#  1758.7391304347825,
#  1767.2857142857142,
#  1764.7142857142858,
#  1767.5454545454545,
#  1729.1,
#  1753.608695652174,
#  1752.7619047619048,
#  1756.65,
#  1719.6842105263158,
#  1490.6842105263158,
#  1619.8,
#  1594.0526315789473,
#  1586.391304347826,
#  1237.6,
#  1237.6363636363637,
#  1203.6818181818182,
#  1252.5263157894738,
#  1211.0434782608695,
#  1206.6,
#  1193.904761904762,
#  1182.7368421052631,
#  1010.5263157894736]

# %% [markdown]
# Index of stations in the system

# %%
dec2017.columns
# Out:
# Index([   'RM',    'EN',    'EP',    'NB',    'BK',    'AS',    'MA',    19.0,
#           12.0,    'LM',    'FV',    'CL',    'SL',    'BF',    'HY',    'SH',
#           'UC',    'FM',    'CN',    'PH',    'WC',    'LF',    'OR',    'RR',
#           'OW',    'EM',    'MT',    'PL',    'CC',    16.0,    24.0,    'GP',
#           'BP',    'DC',    'CM',    'CV',    'ED',    'NC',    'WP',    'SS',
#           'SB',    'SO',    'MB',    'WD',    'OA',    'WS', 'Exits'],
#       dtype='object', name=0)

# %% [markdown]
# ### Scouting Individual High traffic routes and plotting

# %% [markdown]
# #### BARTMAP for reference

# %%
bartmap

# %% [markdown]
# #### Routes from Eastbay To Montegomery Street(Downtown)

# %%
plt.figure(figsize=(12,8))
a = plt.plot(value('WS','MT'),label='Warm Springs')
plt.plot(value('FM','MT'),label ='Fremont')
plt.plot(value('UC','MT'),label = 'Union City')
plt.plot(value('SH','MT'),label = 'South Hayward')
plt.plot(value('HY','MT'), label = 'Hayward')
plt.legend()

# %% [markdown]
# Note: As we can see here, when the WARM SPRINGS station opened in 2017, traffic significantly dropped from the Fremont station but not from the other ones which suggests that people commute from further down the East and South bay to get to the first station

# %% [markdown]
# #### Routes from Pleasonton valley to Downtown SF

# %%
plt.figure(figsize=(12,8))
plt.plot(value('WD','MT'),label ='West Dublin')
plt.plot(value('CV','MT'),label = 'Castro Valley')
plt.plot(value('BF','MT'), label = 'Bay Fair')
plt.legend()

# %% [markdown]
# NOTE: Identifying trends between the monthly changes show as that all the stations from a similar area are directly correlated with each other to almost a perfect degree
#
# ##### In most of these routes, the decrease we see is in the month of december when commuters are on vacation, and hence a consistent dip in traffic in corresponding years as well

# %% [markdown]
# #### Downtown Routes in San Francisco From Embarcadero Station

# %%
plt.figure(figsize=(12,8))
plt.plot(value('EM','PL'),label='Powell')
plt.plot(value('EM','MT'),label='Montogomery')
plt.plot(value('EM','CC'),label='Civic Centre')
plt.plot(value('EM','GP'),label='Glen Park')
plt.legend()

# %% [markdown]
# NOTE: The low traffic between the Embarcadero and Montegomery lines is because they are in essence the 2 closest stations in the BART system, hence a low demand to travel between them

# %% [markdown]
# ### Creating a Dataframe with every possible route for the last 36 months.

# %%
df =pd.DataFrame(pd.Series(value('MT','PL')))

# %%
df = df.T

# %%
df
# Out:
#            0           1           2           3       4           5   \
# 0  309.052632  329.842105  307.681818  322.863636  337.05  346.454545
#
#            6           7           8           9      ...              26  \
# 0  351.545455  309.095238  341.571429  343.952381     ...      322.043478
#
#       27          28          29          30          31      32     33  \
# 0  315.5  312.818182  326.954545  297.315789  303.347826  310.55  287.0
#
#            34          35
# 0  323.736842  382.789474
#
# [1 rows x 36 columns]

# %%
len(list_of_months), df.shape
# Out:
# (36, (1, 36))

# %%
Note : The function below has 2 for loops

# %%
for station in dec2017.columns[:-1]:
    if type(station) == str:
        for stationname in dec2017.columns[:-1]:
            if type(stationname) == str: 
                df = pd.concat([df,pd.DataFrame(value(station,stationname)).T], axis=0)

df
# Out:
#             0           1           2           3       4           5   \
# 0   309.052632  329.842105  307.681818  322.863636  337.05  346.454545
# 0    14.368421   12.157895   13.363636   14.636364   13.15   14.500000
# 0   148.842105  151.210526  150.636364  146.727273  143.30  145.090909
# 0   114.578947  114.263158  118.227273  116.454545  115.75  111.454545
# 0   126.526316  131.052632  127.227273  120.181818  127.30   92.363636
# 0   500.157895  559.842105  541.454545  540.454545  487.75  483.318182
# 0   113.052632  106.736842  107.090909  116.909091  122.50  116.363636
# 0   169.421053  186.315789  187.863636  186.272727  178.15  180.318182
# 0    51.894737   66.000000   59.636364   56.772727   53.70   59.500000
# 0    99.631579  108.105263  105.500000   98.181818  100.45  108.409091
# 0    71.157895   73.947368   79.454545   86.818182   90.40   84.954545
# 0    54.578947   52.947368   48.545455   49.454545   52.25   51.863636
# 0    36.052632   33.210526   37.363636   35.318182   32.70   33.727273
# 0    54.473684   52.578947   49.772727   49.000000   48.35   40.681818
# 0    22.052632   19.684211   20.681818   21.909091   23.05   23.090909
# 0    28.000000   29.052632   29.727273   26.363636   28.10   29.136364
# 0    42.947368   44.368421   44.318182   39.318182   36.40   39.318182
# 0    32.368421   32.526316   33.090909   29.681818   27.40   25.045455
# 0     6.523810    8.263158    7.947368
# 0     9.619048    9.526316   10.736842
# 0    28.761905   24.210526   21.947368
# 0    24.952381   26.000000   25.105263
# 0   474.238095  487.947368  471.736842
# 0   496.190476  512.578947  465.210526
# 0   396.666667  416.210526  409.368421
# 0   323.285714  336.526316  307.842105
# 0    44.619048   48.789474   43.473684
# 0    74.809524   70.421053   62.052632
# ..         ...         ...         ...
# 0    73.714286   73.526316   66.894737
# 0    41.476190   38.894737   38.210526
# 0    42.714286   37.684211   36.052632
# 0    48.285714   39.684211   35.263158
# 0    11.904762   12.631579   10.736842
# 0    10.666667   12.105263    8.894737
# 0     7.190476    6.578947    6.473684
# 0     3.142857    2.000000    2.315789
# 0     2.571429    2.842105    3.315789
# 0     9.857143   10.842105   10.052632
# 0    10.428571   11.052632   14.052632
# 0   764.523810  758.210526  663.736842
# 0   688.285714  689.631579  601.736842
# 0   239.666667  253.105263  248.789474
# 0   243.190476  250.000000  212.947368
# 0     9.619048   12.157895   12.052632
# 0    10.190476   10.315789    9.421053
# 0    37.095238   33.315789   26.578947
# 0     1.619048    1.105263    1.263158
# 0    10.380952    9.736842   11.000000
# 0    24.047619   23.736842   22.789474
# 0     3.190476    2.315789    2.631579
# 0    17.666667   21.842105   24.052632
# 0     2.857143    2.368421    2.157895
# 0     1.476190    2.052632    2.000000
# 0    14.190476   15.842105   12.157895
# 0     0.666667    0.789474    1.105263
# 0     8.857143    8.000000    6.947368
# 0    11.571429   10.789474    9.368421
# 0    23.809524   21.052632   20.578947
#
# [1765 rows x 36 columns]

# %%
df.columns=['jan2015','feb2015','march2015','april2015','may2015','june2015','july2015','aug2015','sept2015','oct2015',
              'nov2015','dec2015','jan2016','feb2016','march2016','april2016','may2016','june2016','july2016','aug2016','sept2016',
            'oct2016','nov2016','dec2016','jan2017','feb2017','march2017','april2017','may2017','june2017','july2017','aug2017','sept2017','oct2017',
              'nov2017','dec2017']

# %%
df.shape
# Out:
# (1765, 36)

# %%
station_pairs = ['drop_row']
for station in dec2017.columns[:-1]:
    if type(station) == str:
        for stationname in dec2017.columns[:-1]:
            if type(stationname) == str: 
                station_pairs.append(station + '-' + stationname)
station_pairs
# Out:
# ['drop_row',
#  'RM-RM',
#  'RM-EN',
#  'RM-EP',
#  'RM-NB',
#  'RM-BK',
#  'RM-AS',
#  'RM-MA',
#  'RM-LM',
#  'RM-FV',
#  'RM-CL',
#  'RM-SL',
#  'RM-BF',
#  'RM-HY',
#  'RM-SH',
#  'RM-UC',
#  'RM-FM',
#  'RM-CN',
#  'RM-PH',
#  'RM-WC',
#  'RM-LF',
#  'RM-OR',
#  'RM-RR',
#  'RM-OW',
#  'RM-EM',
#  'RM-MT',
#  'RM-PL',
#  'RM-CC',
#  'RM-GP',
#  'RM-BP',
#  'RM-DC',
#  'RM-CM',
#  'RM-CV',
#  'RM-ED',
#  'RM-NC',
#  'RM-WP',
#  'RM-SS',
#  'RM-SB',
#  'RM-SO',
#  'RM-MB',
#  'RM-WD',
#  'RM-OA',
#  'RM-WS',
#  'EN-RM',
#  'EN-EN',
#  'EN-EP',
#  'EN-NB',
#  'EN-BK',
#  'EN-AS',
#  'EN-MA',
#  'EN-LM',
#  'EN-FV',
#  'EN-CL',
#  'EN-SL',
#  'EN-BF',
#  'EN-HY',
#  'EN-SH',
#  'EN-UC',
#  'EN-FM',
#  'EN-CN',
#  'EN-PH',
#  'EN-WC',
#  'EN-LF',
#  'EN-OR',
#  'EN-RR',
#  'EN-OW',
#  'EN-EM',
#  'EN-MT',
#  'EN-PL',
#  'EN-CC',
#  'EN-GP',
#  'EN-BP',
#  'EN-DC',
#  'EN-CM',
#  'EN-CV',
#  'EN-ED',
#  'EN-NC',
#  'EN-WP',
#  'EN-SS',
#  'EN-SB',
#  'EN-SO',
#  'EN-MB',
#  'EN-WD',
#  'EN-OA',
#  'EN-WS',
#  'EP-RM',
#  'EP-EN',
#  'EP-EP',
#  'EP-NB',
#  'EP-BK',
#  'EP-AS',
#  'EP-MA',
#  'EP-LM',
#  'EP-FV',
#  'EP-CL',
#  'EP-SL',
#  'EP-BF',
#  'EP-HY',
#  'EP-SH',
#  'EP-UC',
#  'EP-FM',
#  'EP-CN',
#  'EP-PH',
#  'EP-WC',
#  'EP-LF',
#  'EP-OR',
#  'EP-RR',
#  'EP-OW',
#  'EP-EM',
#  'EP-MT',
#  'EP-PL',
#  'EP-CC',
#  'EP-GP',
#  'EP-BP',
#  'EP-DC',
#  'EP-CM',
#  'EP-CV',
#  'EP-ED',
#  'EP-NC',
#  'EP-WP',
#  'EP-SS',
#  'EP-SB',
#  'EP-SO',
#  'EP-MB',
#  'EP-WD',
#  'EP-OA',
#  'EP-WS',
#  'NB-RM',
#  'NB-EN',
#  'NB-EP',
#  'NB-NB',
#  'NB-BK',
#  'NB-AS',
#  'NB-MA',
#  'NB-LM',
#  'NB-FV',
#  'NB-CL',
#  'NB-SL',
#  'NB-BF',
#  'NB-HY',
#  'NB-SH',
#  'NB-UC',
#  'NB-FM',
#  'NB-CN',
#  'NB-PH',
#  'NB-WC',
#  'NB-LF',
#  'NB-OR',
#  'NB-RR',
#  'NB-OW',
#  'NB-EM',
#  'NB-MT',
#  'NB-PL',
#  'NB-CC',
#  'NB-GP',
#  'NB-BP',
#  'NB-DC',
#  'NB-CM',
#  'NB-CV',
#  'NB-ED',
#  'NB-NC',
#  'NB-WP',
#  'NB-SS',
#  'NB-SB',
#  'NB-SO',
#  'NB-MB',
#  'NB-WD',
#  'NB-OA',
#  'NB-WS',
#  'BK-RM',
#  'BK-EN',
#  'BK-EP',
#  'BK-NB',
#  'BK-BK',
#  'BK-AS',
#  'BK-MA',
#  'BK-LM',
#  'BK-FV',
#  'BK-CL',
#  'BK-SL',
#  'BK-BF',
#  'BK-HY',
#  'BK-SH',
#  'BK-UC',
#  'BK-FM',
#  'BK-CN',
#  'BK-PH',
#  'BK-WC',
#  'BK-LF',
#  'BK-OR',
#  'BK-RR',
#  'BK-OW',
#  'BK-EM',
#  'BK-MT',
#  'BK-PL',
#  'BK-CC',
#  'BK-GP',
#  'BK-BP',
#  'BK-DC',
#  'BK-CM',
#  'BK-CV',
#  'BK-ED',
#  'BK-NC',
#  'BK-WP',
#  'BK-SS',
#  'BK-SB',
#  'BK-SO',
#  'BK-MB',
#  'BK-WD',
#  'BK-OA',
#  'BK-WS',
#  'AS-RM',
#  'AS-EN',
#  'AS-EP',
#  'AS-NB',
#  'AS-BK',
#  'AS-AS',
#  'AS-MA',
#  'AS-LM',
#  'AS-FV',
#  'AS-CL',
#  'AS-SL',
#  'AS-BF',
#  'AS-HY',
#  'AS-SH',
#  'AS-UC',
#  'AS-FM',
#  'AS-CN',
#  'AS-PH',
#  'AS-WC',
#  'AS-LF',
#  'AS-OR',
#  'AS-RR',
#  'AS-OW',
#  'AS-EM',
#  'AS-MT',
#  'AS-PL',
#  'AS-CC',
#  'AS-GP',
#  'AS-BP',
#  'AS-DC',
#  'AS-CM',
#  'AS-CV',
#  'AS-ED',
#  'AS-NC',
#  'AS-WP',
#  'AS-SS',
#  'AS-SB',
#  'AS-SO',
#  'AS-MB',
#  'AS-WD',
#  'AS-OA',
#  'AS-WS',
#  'MA-RM',
#  'MA-EN',
#  'MA-EP',
#  'MA-NB',
#  'MA-BK',
#  'MA-AS',
#  'MA-MA',
#  'MA-LM',
#  'MA-FV',
#  'MA-CL',
#  'MA-SL',
#  'MA-BF',
#  'MA-HY',
#  'MA-SH',
#  'MA-UC',
#  'MA-FM',
#  'MA-CN',
#  'MA-PH',
#  'MA-WC',
#  'MA-LF',
#  'MA-OR',
#  'MA-RR',
#  'MA-OW',
#  'MA-EM',
#  'MA-MT',
#  'MA-PL',
#  'MA-CC',
#  'MA-GP',
#  'MA-BP',
#  'MA-DC',
#  'MA-CM',
#  'MA-CV',
#  'MA-ED',
#  'MA-NC',
#  'MA-WP',
#  'MA-SS',
#  'MA-SB',
#  'MA-SO',
#  'MA-MB',
#  'MA-WD',
#  'MA-OA',
#  'MA-WS',
#  'LM-RM',
#  'LM-EN',
#  'LM-EP',
#  'LM-NB',
#  'LM-BK',
#  'LM-AS',
#  'LM-MA',
#  'LM-LM',
#  'LM-FV',
#  'LM-CL',
#  'LM-SL',
#  'LM-BF',
#  'LM-HY',
#  'LM-SH',
#  'LM-UC',
#  'LM-FM',
#  'LM-CN',
#  'LM-PH',
#  'LM-WC',
#  'LM-LF',
#  'LM-OR',
#  'LM-RR',
#  'LM-OW',
#  'LM-EM',
#  'LM-MT',
#  'LM-PL',
#  'LM-CC',
#  'LM-GP',
#  'LM-BP',
#  'LM-DC',
#  'LM-CM',
#  'LM-CV',
#  'LM-ED',
#  'LM-NC',
#  'LM-WP',
#  'LM-SS',
#  'LM-SB',
#  'LM-SO',
#  'LM-MB',
#  'LM-WD',
#  'LM-OA',
#  'LM-WS',
#  'FV-RM',
#  'FV-EN',
#  'FV-EP',
#  'FV-NB',
#  'FV-BK',
#  'FV-AS',
#  'FV-MA',
#  'FV-LM',
#  'FV-FV',
#  'FV-CL',
#  'FV-SL',
#  'FV-BF',
#  'FV-HY',
#  'FV-SH',
#  'FV-UC',
#  'FV-FM',
#  'FV-CN',
#  'FV-PH',
#  'FV-WC',
#  'FV-LF',
#  'FV-OR',
#  'FV-RR',
#  'FV-OW',
#  'FV-EM',
#  'FV-MT',
#  'FV-PL',
#  'FV-CC',
#  'FV-GP',
#  'FV-BP',
#  'FV-DC',
#  'FV-CM',
#  'FV-CV',
#  'FV-ED',
#  'FV-NC',
#  'FV-WP',
#  'FV-SS',
#  'FV-SB',
#  'FV-SO',
#  'FV-MB',
#  'FV-WD',
#  'FV-OA',
#  'FV-WS',
#  'CL-RM',
#  'CL-EN',
#  'CL-EP',
#  'CL-NB',
#  'CL-BK',
#  'CL-AS',
#  'CL-MA',
#  'CL-LM',
#  'CL-FV',
#  'CL-CL',
#  'CL-SL',
#  'CL-BF',
#  'CL-HY',
#  'CL-SH',
#  'CL-UC',
#  'CL-FM',
#  'CL-CN',
#  'CL-PH',
#  'CL-WC',
#  'CL-LF',
#  'CL-OR',
#  'CL-RR',
#  'CL-OW',
#  'CL-EM',
#  'CL-MT',
#  'CL-PL',
#  'CL-CC',
#  'CL-GP',
#  'CL-BP',
#  'CL-DC',
#  'CL-CM',
#  'CL-CV',
#  'CL-ED',
#  'CL-NC',
#  'CL-WP',
#  'CL-SS',
#  'CL-SB',
#  'CL-SO',
#  'CL-MB',
#  'CL-WD',
#  'CL-OA',
#  'CL-WS',
#  'SL-RM',
#  'SL-EN',
#  'SL-EP',
#  'SL-NB',
#  'SL-BK',
#  'SL-AS',
#  'SL-MA',
#  'SL-LM',
#  'SL-FV',
#  'SL-CL',
#  'SL-SL',
#  'SL-BF',
#  'SL-HY',
#  'SL-SH',
#  'SL-UC',
#  'SL-FM',
#  'SL-CN',
#  'SL-PH',
#  'SL-WC',
#  'SL-LF',
#  'SL-OR',
#  'SL-RR',
#  'SL-OW',
#  'SL-EM',
#  'SL-MT',
#  'SL-PL',
#  'SL-CC',
#  'SL-GP',
#  'SL-BP',
#  'SL-DC',
#  'SL-CM',
#  'SL-CV',
#  'SL-ED',
#  'SL-NC',
#  'SL-WP',
#  'SL-SS',
#  'SL-SB',
#  'SL-SO',
#  'SL-MB',
#  'SL-WD',
#  'SL-OA',
#  'SL-WS',
#  'BF-RM',
#  'BF-EN',
#  'BF-EP',
#  'BF-NB',
#  'BF-BK',
#  'BF-AS',
#  'BF-MA',
#  'BF-LM',
#  'BF-FV',
#  'BF-CL',
#  'BF-SL',
#  'BF-BF',
#  'BF-HY',
#  'BF-SH',
#  'BF-UC',
#  'BF-FM',
#  'BF-CN',
#  'BF-PH',
#  'BF-WC',
#  'BF-LF',
#  'BF-OR',
#  'BF-RR',
#  'BF-OW',
#  'BF-EM',
#  'BF-MT',
#  'BF-PL',
#  'BF-CC',
#  'BF-GP',
#  'BF-BP',
#  'BF-DC',
#  'BF-CM',
#  'BF-CV',
#  'BF-ED',
#  'BF-NC',
#  'BF-WP',
#  'BF-SS',
#  'BF-SB',
#  'BF-SO',
#  'BF-MB',
#  'BF-WD',
#  'BF-OA',
#  'BF-WS',
#  'HY-RM',
#  'HY-EN',
#  'HY-EP',
#  'HY-NB',
#  'HY-BK',
#  'HY-AS',
#  'HY-MA',
#  'HY-LM',
#  'HY-FV',
#  'HY-CL',
#  'HY-SL',
#  'HY-BF',
#  'HY-HY',
#  'HY-SH',
#  'HY-UC',
#  'HY-FM',
#  'HY-CN',
#  'HY-PH',
#  'HY-WC',
#  'HY-LF',
#  'HY-OR',
#  'HY-RR',
#  'HY-OW',
#  'HY-EM',
#  'HY-MT',
#  'HY-PL',
#  'HY-CC',
#  'HY-GP',
#  'HY-BP',
#  'HY-DC',
#  'HY-CM',
#  'HY-CV',
#  'HY-ED',
#  'HY-NC',
#  'HY-WP',
#  'HY-SS',
#  'HY-SB',
#  'HY-SO',
#  'HY-MB',
#  'HY-WD',
#  'HY-OA',
#  'HY-WS',
#  'SH-RM',
#  'SH-EN',
#  'SH-EP',
#  'SH-NB',
#  'SH-BK',
#  'SH-AS',
#  'SH-MA',
#  'SH-LM',
#  'SH-FV',
#  'SH-CL',
#  'SH-SL',
#  'SH-BF',
#  'SH-HY',
#  'SH-SH',
#  'SH-UC',
#  'SH-FM',
#  'SH-CN',
#  'SH-PH',
#  'SH-WC',
#  'SH-LF',
#  'SH-OR',
#  'SH-RR',
#  'SH-OW',
#  'SH-EM',
#  'SH-MT',
#  'SH-PL',
#  'SH-CC',
#  'SH-GP',
#  'SH-BP',
#  'SH-DC',
#  'SH-CM',
#  'SH-CV',
#  'SH-ED',
#  'SH-NC',
#  'SH-WP',
#  'SH-SS',
#  'SH-SB',
#  'SH-SO',
#  'SH-MB',
#  'SH-WD',
#  'SH-OA',
#  'SH-WS',
#  'UC-RM',
#  'UC-EN',
#  'UC-EP',
#  'UC-NB',
#  'UC-BK',
#  'UC-AS',
#  'UC-MA',
#  'UC-LM',
#  'UC-FV',
#  'UC-CL',
#  'UC-SL',
#  'UC-BF',
#  'UC-HY',
#  'UC-SH',
#  'UC-UC',
#  'UC-FM',
#  'UC-CN',
#  'UC-PH',
#  'UC-WC',
#  'UC-LF',
#  'UC-OR',
#  'UC-RR',
#  'UC-OW',
#  'UC-EM',
#  'UC-MT',
#  'UC-PL',
#  'UC-CC',
#  'UC-GP',
#  'UC-BP',
#  'UC-DC',
#  'UC-CM',
#  'UC-CV',
#  'UC-ED',
#  'UC-NC',
#  'UC-WP',
#  'UC-SS',
#  'UC-SB',
#  'UC-SO',
#  'UC-MB',
#  'UC-WD',
#  'UC-OA',
#  'UC-WS',
#  'FM-RM',
#  'FM-EN',
#  'FM-EP',
#  'FM-NB',
#  'FM-BK',
#  'FM-AS',
#  'FM-MA',
#  'FM-LM',
#  'FM-FV',
#  'FM-CL',
#  'FM-SL',
#  'FM-BF',
#  'FM-HY',
#  'FM-SH',
#  'FM-UC',
#  'FM-FM',
#  'FM-CN',
#  'FM-PH',
#  'FM-WC',
#  'FM-LF',
#  'FM-OR',
#  'FM-RR',
#  'FM-OW',
#  'FM-EM',
#  'FM-MT',
#  'FM-PL',
#  'FM-CC',
#  'FM-GP',
#  'FM-BP',
#  'FM-DC',
#  'FM-CM',
#  'FM-CV',
#  'FM-ED',
#  'FM-NC',
#  'FM-WP',
#  'FM-SS',
#  'FM-SB',
#  'FM-SO',
#  'FM-MB',
#  'FM-WD',
#  'FM-OA',
#  'FM-WS',
#  'CN-RM',
#  'CN-EN',
#  'CN-EP',
#  'CN-NB',
#  'CN-BK',
#  'CN-AS',
#  'CN-MA',
#  'CN-LM',
#  'CN-FV',
#  'CN-CL',
#  'CN-SL',
#  'CN-BF',
#  'CN-HY',
#  'CN-SH',
#  'CN-UC',
#  'CN-FM',
#  'CN-CN',
#  'CN-PH',
#  'CN-WC',
#  'CN-LF',
#  'CN-OR',
#  'CN-RR',
#  'CN-OW',
#  'CN-EM',
#  'CN-MT',
#  'CN-PL',
#  'CN-CC',
#  'CN-GP',
#  'CN-BP',
#  'CN-DC',
#  'CN-CM',
#  'CN-CV',
#  'CN-ED',
#  'CN-NC',
#  'CN-WP',
#  'CN-SS',
#  'CN-SB',
#  'CN-SO',
#  'CN-MB',
#  'CN-WD',
#  'CN-OA',
#  'CN-WS',
#  'PH-RM',
#  'PH-EN',
#  'PH-EP',
#  'PH-NB',
#  'PH-BK',
#  'PH-AS',
#  'PH-MA',
#  'PH-LM',
#  'PH-FV',
#  'PH-CL',
#  'PH-SL',
#  'PH-BF',
#  'PH-HY',
#  'PH-SH',
#  'PH-UC',
#  'PH-FM',
#  'PH-CN',
#  'PH-PH',
#  'PH-WC',
#  'PH-LF',
#  'PH-OR',
#  'PH-RR',
#  'PH-OW',
#  'PH-EM',
#  'PH-MT',
#  'PH-PL',
#  'PH-CC',
#  'PH-GP',
#  'PH-BP',
#  'PH-DC',
#  'PH-CM',
#  'PH-CV',
#  'PH-ED',
#  'PH-NC',
#  'PH-WP',
#  'PH-SS',
#  'PH-SB',
#  'PH-SO',
#  'PH-MB',
#  'PH-WD',
#  'PH-OA',
#  'PH-WS',
#  'WC-RM',
#  'WC-EN',
#  'WC-EP',
#  'WC-NB',
#  'WC-BK',
#  'WC-AS',
#  'WC-MA',
#  'WC-LM',
#  'WC-FV',
#  'WC-CL',
#  'WC-SL',
#  'WC-BF',
#  'WC-HY',
#  'WC-SH',
#  'WC-UC',
#  'WC-FM',
#  'WC-CN',
#  'WC-PH',
#  'WC-WC',
#  'WC-LF',
#  'WC-OR',
#  'WC-RR',
#  'WC-OW',
#  'WC-EM',
#  'WC-MT',
#  'WC-PL',
#  'WC-CC',
#  'WC-GP',
#  'WC-BP',
#  'WC-DC',
#  'WC-CM',
#  'WC-CV',
#  'WC-ED',
#  'WC-NC',
#  'WC-WP',
#  'WC-SS',
#  'WC-SB',
#  'WC-SO',
#  'WC-MB',
#  'WC-WD',
#  'WC-OA',
#  'WC-WS',
#  'LF-RM',
#  'LF-EN',
#  'LF-EP',
#  'LF-NB',
#  'LF-BK',
#  'LF-AS',
#  'LF-MA',
#  'LF-LM',
#  'LF-FV',
#  'LF-CL',
#  'LF-SL',
#  'LF-BF',
#  'LF-HY',
#  'LF-SH',
#  'LF-UC',
#  'LF-FM',
#  'LF-CN',
#  'LF-PH',
#  'LF-WC',
#  'LF-LF',
#  'LF-OR',
#  'LF-RR',
#  'LF-OW',
#  'LF-EM',
#  'LF-MT',
#  'LF-PL',
#  'LF-CC',
#  'LF-GP',
#  'LF-BP',
#  'LF-DC',
#  'LF-CM',
#  'LF-CV',
#  'LF-ED',
#  'LF-NC',
#  'LF-WP',
#  'LF-SS',
#  'LF-SB',
#  'LF-SO',
#  'LF-MB',
#  'LF-WD',
#  'LF-OA',
#  'LF-WS',
#  'OR-RM',
#  'OR-EN',
#  'OR-EP',
#  'OR-NB',
#  'OR-BK',
#  'OR-AS',
#  'OR-MA',
#  'OR-LM',
#  'OR-FV',
#  'OR-CL',
#  'OR-SL',
#  'OR-BF',
#  'OR-HY',
#  'OR-SH',
#  'OR-UC',
#  'OR-FM',
#  'OR-CN',
#  'OR-PH',
#  'OR-WC',
#  'OR-LF',
#  'OR-OR',
#  'OR-RR',
#  'OR-OW',
#  'OR-EM',
#  'OR-MT',
#  'OR-PL',
#  'OR-CC',
#  'OR-GP',
#  'OR-BP',
#  'OR-DC',
#  'OR-CM',
#  'OR-CV',
#  'OR-ED',
#  'OR-NC',
#  'OR-WP',
#  'OR-SS',
#  'OR-SB',
#  'OR-SO',
#  'OR-MB',
#  'OR-WD',
#  'OR-OA',
#  'OR-WS',
#  'RR-RM',
#  'RR-EN',
#  'RR-EP',
#  'RR-NB',
#  'RR-BK',
#  'RR-AS',
#  'RR-MA',
#  'RR-LM',
#  'RR-FV',
#  'RR-CL',
#  'RR-SL',
#  'RR-BF',
#  'RR-HY',
#  'RR-SH',
#  'RR-UC',
#  'RR-FM',
#  'RR-CN',
#  'RR-PH',
#  'RR-WC',
#  'RR-LF',
#  'RR-OR',
#  'RR-RR',
#  'RR-OW',
#  'RR-EM',
#  'RR-MT',
#  'RR-PL',
#  'RR-CC',
#  'RR-GP',
#  'RR-BP',
#  'RR-DC',
#  'RR-CM',
#  'RR-CV',
#  'RR-ED',
#  'RR-NC',
#  'RR-WP',
#  'RR-SS',
#  'RR-SB',
#  'RR-SO',
#  'RR-MB',
#  'RR-WD',
#  'RR-OA',
#  'RR-WS',
#  'OW-RM',
#  'OW-EN',
#  'OW-EP',
#  'OW-NB',
#  'OW-BK',
#  'OW-AS',
#  'OW-MA',
#  'OW-LM',
#  'OW-FV',
#  'OW-CL',
#  'OW-SL',
#  'OW-BF',
#  'OW-HY',
#  'OW-SH',
#  'OW-UC',
#  'OW-FM',
#  'OW-CN',
#  'OW-PH',
#  'OW-WC',
#  'OW-LF',
#  'OW-OR',
#  'OW-RR',
#  'OW-OW',
#  'OW-EM',
#  'OW-MT',
#  'OW-PL',
#  'OW-CC',
#  'OW-GP',
#  'OW-BP',
#  'OW-DC',
#  'OW-CM',
#  'OW-CV',
#  'OW-ED',
#  'OW-NC',
#  'OW-WP',
#  'OW-SS',
#  'OW-SB',
#  'OW-SO',
#  'OW-MB',
#  'OW-WD',
#  'OW-OA',
#  'OW-WS',
#  'EM-RM',
#  'EM-EN',
#  'EM-EP',
#  'EM-NB',
#  'EM-BK',
#  'EM-AS',
#  'EM-MA',
#  'EM-LM',
#  'EM-FV',
#  'EM-CL',
#  'EM-SL',
#  'EM-BF',
#  'EM-HY',
#  'EM-SH',
#  'EM-UC',
#  'EM-FM',
#  'EM-CN',
#  'EM-PH',
#  'EM-WC',
#  'EM-LF',
#  'EM-OR',
#  'EM-RR',
#  'EM-OW',
#  'EM-EM',
#  'EM-MT',
#  'EM-PL',
#  'EM-CC',
#  'EM-GP',
#  'EM-BP',
#  'EM-DC',
#  'EM-CM',
#  'EM-CV',
#  'EM-ED',
#  ...]

# %%
len(station_pairs)
# Out:
# 1765

# %%
df['stations'] = pd.Series(station_pairs).values

# %%
df = df.set_index('stations')

# %%
df = df.iloc[1:]

# %%
df
# Out:
#              jan2015     feb2015   march2015   april2015  may2015    june2015  \
# stations
# RM-RM      14.368421   12.157895   13.363636   14.636364    13.15   14.500000
# RM-EN     148.842105  151.210526  150.636364  146.727273   143.30  145.090909
# RM-EP     114.578947  114.263158  118.227273  116.454545   115.75  111.454545
# RM-NB     126.526316  131.052632  127.227273  120.181818   127.30   92.363636
# RM-BK     500.157895  559.842105  541.454545  540.454545   487.75  483.318182
# RM-AS     113.052632  106.736842  107.090909  116.909091   122.50  116.363636
# RM-MA     169.421053  186.315789  187.863636  186.272727   178.15  180.318182
# RM-LM      51.894737   66.000000   59.636364   56.772727    53.70   59.500000
# RM-FV      99.631579  108.105263  105.500000   98.181818   100.45  108.409091
# RM-CL      71.157895   73.947368   79.454545   86.818182    90.40   84.954545
# RM-SL      54.578947   52.947368   48.545455   49.454545    52.25   51.863636
# RM-BF      36.052632   33.210526   37.363636   35.318182    32.70   33.727273
# RM-HY      54.473684   52.578947   49.772727   49.000000    48.35   40.681818
# RM-SH      22.052632   19.684211   20.681818   21.909091    23.05   23.090909
# RM-UC      28.000000   29.052632   29.727273   26.363636    28.10   29.136364
# RM-FM      42.947368   44.368421   44.318182   39.318182    36.40   39.318182
# RM-CN      32.368421   32.526316   33.090909   29.681818    27.40   25.045455
# RM-PH      14.368421   15.947368   16.318182   14.727273    14.35   16.727273
# RM-WC      23.789474   24.947368   26.590909   24.409091    24.60   25.227273
# RM-LF      11.789474   12.578947   11.681818    9.454545    11.55   11.136364
# RM-OR       9.000000    8.578947    7.954545    8.818182     9.65    8.909091
# RM-RR      24.894737   24.631579   24.818182   21.681818    25.05   23.409091
# RM-OW      26.157895   27.157895   28.727273   28.636364    26.15   23.454545
# RM-EM     384.263158  400.421053  414.000000  425.045455   419.35  434.227273
# RM-MT     407.684211  422.894737  423.227273  440.045455   436.55  463.954545
# RM-PL     375.105263  386.578947  401.727273  408.727273   374.70  397.727273
# RM-CC     306.315789  310.210526  310.454545  304.409091   305.85  313.954545
# RM-GP      38.315789   34.684211   34.772727   39.181818    41.80   43.181818
# RM-BP      62.157895   67.421053   65.727273   70.090909    66.70   55.818182
# RM-DC      60.000000  105.631579   81.045455  101.727273    77.20   46.636364
# ...              ...         ...         ...         ...      ...         ...
# WS-HY       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-SH       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-UC       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-FM       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-CN       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-PH       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-WC       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-LF       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-OR       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-RR       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-OW       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-EM       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-MT       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-PL       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-CC       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-GP       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-BP       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-DC       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-CM       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-CV       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-ED       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-NC       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-WP       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-SS       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-SB       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-SO       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-MB       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-WD       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-OA       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
# WS-WS       0.000000    0.000000    0.000000    0.000000     0.00    0.000000
#
#             july2015     aug2015    sept2015     oct2015     ...      \
# stations                                                     ...
# RM-RM      15.409091   14.000000   15.952381   13.238095     ...
# RM-EN     144.136364  147.761905  159.619048  165.000000     ...
# RM-EP     113.090909  113.761905  117.857143  122.333333     ...
# RM-NB      78.772727   88.285714  111.238095  113.761905     ...
# RM-BK     477.636364  471.714286  557.571429  553.047619     ...
# RM-AS     112.727273  118.000000  121.285714  122.285714     ...
# RM-MA     174.409091  183.238095  190.523810  187.380952     ...
# RM-LM      49.863636   49.619048   71.333333   72.857143     ...
# RM-FV     110.727273  106.571429  110.333333  106.047619     ...
# RM-CL      81.090909   94.000000   82.523810   78.571429     ...
# RM-SL      52.818182   52.476190   55.571429   58.428571     ...
# RM-BF      31.636364   34.238095   33.857143   34.952381     ...
# RM-HY      40.272727   40.904762   39.285714   59.904762     ...
# RM-SH      24.454545   22.904762   22.190476   24.952381     ...
# RM-UC      26.454545   27.952381   31.857143   29.238095     ...
# RM-FM      35.636364   37.285714   41.619048   45.000000     ...
# RM-CN      28.181818   30.333333   33.000000   32.904762     ...
# RM-PH      14.500000   17.142857   17.285714   16.857143     ...
# RM-WC      24.818182   24.428571   27.523810   32.142857     ...
# RM-LF       9.909091    9.095238   11.666667    9.523810     ...
# RM-OR      11.727273    8.714286    7.095238    7.666667     ...
# RM-RR      24.181818   25.142857   30.285714   29.666667     ...
# RM-OW      24.727273   27.380952   26.666667   31.047619     ...
# RM-EM     436.136364  446.666667  441.476190  433.714286     ...
# RM-MT     478.181818  474.476190  475.571429  460.047619     ...
# RM-PL     415.272727  415.761905  425.000000  433.333333     ...
# RM-CC     320.090909  330.428571  341.380952  347.000000     ...
# RM-GP      42.136364   42.952381   41.809524   40.476190     ...
# RM-BP      57.045455   68.142857   73.428571   73.476190     ...
# RM-DC      52.409091   73.333333  114.761905  107.238095     ...
# ...              ...         ...         ...         ...     ...
# WS-HY       0.000000    0.000000    0.000000    0.000000     ...
# WS-SH       0.000000    0.000000    0.000000    0.000000     ...
# WS-UC       0.000000    0.000000    0.000000    0.000000     ...
# WS-FM       0.000000    0.000000    0.000000    0.000000     ...
# WS-CN       0.000000    0.000000    0.000000    0.000000     ...
# WS-PH       0.000000    0.000000    0.000000    0.000000     ...
# WS-WC       0.000000    0.000000    0.000000    0.000000     ...
# WS-LF       0.000000    0.000000    0.000000    0.000000     ...
# WS-OR       0.000000    0.000000    0.000000    0.000000     ...
# WS-RR       0.000000    0.000000    0.000000    0.000000     ...
# WS-OW       0.000000    0.000000    0.000000    0.000000     ...
# WS-EM       0.000000    0.000000    0.000000    0.000000     ...
# WS-MT       0.000000    0.000000    0.000000    0.000000     ...
# WS-PL       0.000000    0.000000    0.000000    0.000000     ...
# WS-CC       0.000000    0.000000    0.000000    0.000000     ...
# WS-GP       0.000000    0.000000    0.000000    0.000000     ...
# WS-BP       0.000000    0.000000    0.000000    0.000000     ...
# WS-DC       0.000000    0.000000    0.000000    0.000000     ...
# WS-CM       0.000000    0.000000    0.000000    0.000000     ...
# WS-CV       0.000000    0.000000    0.000000    0.000000     ...
# WS-ED       0.000000    0.000000    0.000000    0.000000     ...
# WS-NC       0.000000    0.000000    0.000000    0.000000     ...
# WS-WP       0.000000    0.000000    0.000000    0.000000     ...
# WS-SS       0.000000    0.000000    0.000000    0.000000     ...
# WS-SB       0.000000    0.000000    0.000000    0.000000     ...
# WS-SO       0.000000    0.000000    0.000000    0.000000     ...
# WS-MB       0.000000    0.000000    0.000000    0.000000     ...
# WS-WD       0.000000    0.000000    0.000000    0.000000     ...
# WS-OA       0.000000    0.000000    0.000000    0.000000     ...
# WS-WS       0.000000    0.000000    0.000000    0.000000     ...
#
#            march2017  april2017     may2017    june2017    july2017  \
# stations
# RM-RM      13.521739      10.80   12.318182   13.181818   12.736842
# RM-EN     151.869565     142.15  144.090909  135.000000  128.526316
# RM-EP     109.347826     104.25  105.318182   95.090909   90.210526
# RM-NB      87.521739      78.20   82.545455   67.727273   60.526316
# RM-BK     507.173913     496.55  463.136364  433.363636  446.157895
# RM-AS     114.826087     110.15  120.818182  114.500000  112.315789
# RM-MA     169.739130     160.05  169.681818  162.590909  151.315789
# RM-LM      49.434783      44.45   43.863636   55.045455   44.157895
# RM-FV      93.043478      88.60   92.636364   90.636364   90.210526
# RM-CL      66.869565      74.75   75.909091   76.454545   76.052632
# RM-SL      39.739130      38.85   37.636364   35.636364   33.526316
# RM-BF      26.782609      23.15   21.909091   22.863636   21.473684
# RM-HY      36.565217      38.55   38.818182   25.863636   26.473684
# RM-SH      21.434783      20.90   19.681818   18.136364   16.473684
# RM-UC      21.913043      21.25   19.318182   22.045455   20.368421
# RM-FM      40.826087      36.15   32.681818   33.954545   32.578947
# RM-CN      24.565217      21.60   20.090909   21.090909   20.789474
# RM-PH      15.434783      17.05   17.318182   15.318182   13.052632
# RM-WC      27.521739      25.25   25.227273   27.363636   22.789474
# RM-LF       8.173913      10.05    8.636364    8.045455    7.000000
# RM-OR       9.521739       8.70    8.000000    7.818182    6.578947
# RM-RR      24.739130      25.15   24.545455   21.727273   20.315789
# RM-OW      25.304348      25.80   25.090909   27.409091   26.368421
# RM-EM     490.565217     492.20  476.590909  467.136364  475.842105
# RM-MT     444.347826     436.00  462.272727  475.454545  494.157895
# RM-PL     383.565217     377.95  377.954545  393.954545  406.631579
# RM-CC     313.695652     314.65  307.454545  322.545455  314.263158
# RM-FM      33.869565     35.45   35.238095   33.526316   31.894737
# RM-CN      24.086957     23.30   26.428571   29.157895   27.526316
# RM-PH      14.086957     15.70   15.428571   18.315789   15.526316
# RM-WC      22.130435     22.35   23.000000   25.947368   23.684211
# RM-LF       7.086957      6.25    6.523810    8.263158    7.947368
# RM-OR       7.391304     10.00    9.619048    9.526316   10.736842
# RM-RR      20.130435     25.70   28.761905   24.210526   21.947368
# RM-OW      26.826087     26.55   24.952381   26.000000   25.105263
# RM-EM     464.086957    463.10  474.238095  487.947368  471.736842
# RM-MT     470.608696    483.00  496.190476  512.578947  465.210526
# RM-PL     391.391304    390.20  396.666667  416.210526  409.368421
# RM-CC     312.173913    316.85  323.285714  336.526316  307.842105
# RM-GP      47.478261     53.55   44.619048   48.789474   43.473684
# RM-BP      54.304348     70.90   74.809524   70.421053   62.052632
# RM-DC      56.173913    132.10  122.095238  115.894737   82.052632
# ...              ...       ...         ...         ...         ...
# WS-HY      71.217391     72.15   73.714286   73.526316   66.894737
# WS-SH      39.956522     42.45   41.476190   38.894737   38.210526
# WS-UC      49.086957     47.45   42.714286   37.684211   36.052632
# WS-FM      61.434783     49.10   48.285714   39.684211   35.263158
# WS-CN      11.043478     12.75   11.904762   12.631579   10.736842
# WS-PH       9.695652     10.55   10.666667   12.105263    8.894737
# WS-WC       6.478261      6.20    7.190476    6.578947    6.473684
# WS-LF       3.043478      2.80    3.142857    2.000000    2.315789
# WS-OR       3.086957      2.35    2.571429    2.842105    3.315789
# WS-RR       9.695652     10.30    9.857143   10.842105   10.052632
# WS-OW      13.130435     11.60   10.428571   11.052632   14.052632
# WS-EM     744.956522    756.15  764.523810  758.210526  663.736842
# WS-MT     645.347826    672.85  688.285714  689.631579  601.736842
# WS-PL     204.304348    206.95  239.666667  253.105263  248.789474
# WS-CC     227.130435    229.65  243.190476  250.000000  212.947368
# WS-GP      12.913043      9.15    9.619048   12.157895   12.052632
# WS-BP       7.434783     10.05   10.190476   10.315789    9.421053
# WS-DC      16.913043     35.60   37.095238   33.315789   26.578947
# WS-CM       0.826087      1.20    1.619048    1.105263    1.263158
# WS-CV       9.000000      9.10   10.380952    9.736842   11.000000
# WS-ED      26.739130     26.65   24.047619   23.736842   22.789474
# WS-NC       2.304348      3.05    3.190476    2.315789    2.631579
# WS-WP      16.304348     17.50   17.666667   21.842105   24.052632
# WS-SS       2.869565      3.25    2.857143    2.368421    2.157895
# WS-SB       2.000000      1.10    1.476190    2.052632    2.000000
# WS-SO      15.782609     15.00   14.190476   15.842105   12.157895
# WS-MB       1.434783      0.70    0.666667    0.789474    1.105263
# WS-WD      11.130435      8.80    8.857143    8.000000    6.947368
# WS-OA      11.304348     13.30   11.571429   10.789474    9.368421
# WS-WS      22.086957     22.75   23.809524   21.052632   20.578947
#
# [1764 rows x 36 columns]

# %% [markdown]
# The bottem left part of the dataframe contains zeroes as the WARM SPRINGS BART station only opened up in the beggining of 2017

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression

# %%
# Create our X and y dataframes.
X = df.drop('dec2017',axis=1)
y = df['dec2017']

# Do a train-test split. Let's plan on using a test_size of 33%.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.30,
                                                    random_state=42)



# What is step 1 when building a linear regression model?

linmod= LinearRegression()

# What is step 2 when building a linear regression model?
linmod.fit(X_train,y_train)

# Print out the intercept and coefficients.
print(linmod.intercept_)
print(linmod.coef_)
# Out:
# -0.2357157034778652
# [ 0.25400443 -0.25570938  0.13218643 -0.20958768 -0.02155814 -0.02146213
#  -0.03546118  0.04591835 -0.02779412  0.20855322 -0.22804717  0.28779051
#  -0.05625496 -0.0778751  -0.14819868  0.32509716  0.02895205 -0.29890491
#   0.31528096 -0.088254   -0.06166527 -0.20999495 -0.29849511  0.56150082
#  -0.11615208  0.04197981  0.03040823  0.00930989  0.10319626  0.05641756
#  -0.0883936   0.04325466 -0.051446    0.1927865   0.63410955]

# %%
predictions= linmod.predict(X_test)

score =linmod.score(X_test,y_test)
score
# Out:
# 0.9992029075975579

# %%
predictions
# Out:
# array([3.19052807e+02, 8.26092668e+01, 1.39195542e+01, 2.94553504e+01,
#        5.38279734e+01, 4.89022410e+01, 1.81309066e+01, 3.17057334e+02,
#        1.53239710e+01, 8.67482290e+00, 8.89037403e+01, 1.66039483e+02,
#        1.41704310e+01, 4.12224882e+00, 5.29318067e+00, 4.63115981e+01,
#        1.57262941e+02, 8.00074308e+01, 1.88000455e+01, 1.05522457e+03,
#        1.17266525e+02, 4.69323111e+01, 5.62628109e+01, 2.24222984e+01,
#        2.19374418e+02, 1.79391419e+01, 8.09905037e+01, 2.79132766e+01,
#        1.06876052e+02, 8.74725489e+01, 7.49126621e+01, 9.49257515e+00,
#        2.23549044e+01, 1.98087235e+01, 6.92383078e+01, 3.94950816e+02,
#        2.14661816e+01, 8.78902500e+01, 1.37856030e+01, 1.50410576e+02,
#        7.26450599e+02, 8.32173328e+01, 5.37160915e+00, 9.51083712e+00,
#        1.35643602e+02, 3.09197170e+00, 2.84582022e+01, 2.33966379e+01,
#        1.92236745e+00, 2.86204066e+01, 1.34054190e+02, 1.57889127e+01,
#        5.94362289e+00, 1.13055013e+02, 6.07986863e+00, 1.71132072e+01,
#        2.74023026e+01, 2.70145488e+01, 1.13279996e+01, 7.57432418e+01,
#        1.05246188e+03, 4.60230051e+02, 1.15564547e+01, 1.83262885e+01,
#        2.14875171e+01, 1.15999651e+02, 4.24325069e+02, 6.75295244e+01,
#        7.88045403e+00, 5.56386085e+01, 8.34941197e+01, 6.53808512e+01,
#        4.59528697e+01, 1.64014361e+01, 3.30691935e+02, 1.62377900e+01,
#        3.23528686e+01, 3.02894736e+02, 6.05496684e+02, 1.00359016e+01,
#        9.17916124e+01, 7.15664459e+02, 1.87370129e+02, 6.75342679e+00,
#        9.94785865e+02, 9.17134812e+00, 1.28700623e+01, 5.76868446e+01,
#        4.78809363e+00, 4.63516476e+01, 4.11210832e+01, 1.31421074e+01,
#        1.09959418e+01, 4.78829617e+02, 8.99311273e+00, 2.96985275e+01,
y_train
# Out:
# stations
# UC-OW       9.368421
# DC-SS      76.947368
# CM-SH       4.526316
# SL-CV      40.368421
# BF-BP      45.736842
# CM-WS       1.789474
# MA-SS      29.000000
# BP-CN      54.842105
# WS-GP      12.052632
# BP-PL    2069.947368
# DC-EP      47.157895
# SH-SO      20.263158
# CV-EP       4.315789
# CC-SH     222.210526
# RR-WP      70.842105
# WP-DC     129.368421
# LM-NC       8.421053
# SB-BF      16.210526
# WC-DC      60.315789
# RR-EM    1170.736842
# PH-OW      10.684211
# CN-BP      44.894737
# BK-CL     148.421053
# WP-CC     521.368421
# CM-GP      58.526316
# EP-EP      11.210526
# DC-WC      64.526316
# WD-CV      81.526316
# SL-SO      47.842105
# EN-HY      57.000000
#             ...
# OW-CV      13.315789
# BP-WD      25.210526
# CL-LM     213.421053
# LF-LM       9.789474
# WP-CL      99.315789
# SB-NB       9.578947
# FV-LM     148.473684
# WC-SH      14.842105
# CV-CM       2.526316
# OA-AS      24.315789
# NB-BK     185.105263
# OA-LM      24.736842
# OR-CV       2.105263
# CC-CV     243.736842
# NC-SL       6.473684
# EP-NB      50.789474
# SS-HY       7.684211
# LM-SB      18.894737
# DC-OR      17.368421
# BF-BK     135.263158
# EP-SO      76.684211
# WD-RM       8.421053
# MT-SB     662.315789
# WS-EP       9.315789
# CC-NB     441.421053
# CC-MB     538.263158
# CM-WP      34.526316
# OR-OR       9.894737
# WP-CV       2.526316
# CC-WP     635.157895
# Name: dec2017, Length: 1234, dtype: float64

# %%
y_test
# Out:
# stations
# CC-FM     334.631579
# AS-EP      79.473684
# WS-NB      14.842105
# SB-MA      28.210526
# CM-SB      52.210526
# WC-CL      51.315789
# OA-RR      16.526316
# HY-PL     319.421053
# GP-OA      16.315789
# SL-CM       7.684211
# WD-BF      88.789474
# FV-MA     159.315789
# LF-FV      17.421053
# OR-NC       4.894737
# CM-HY       7.526316
# AS-DC      44.157895
# SH-FM     154.368421
# WS-BK      72.263158
# AS-WS      17.894737
# EN-EM    1072.894737
# ED-FV     126.263158
# AS-SL      46.157895
# OR-RR      55.368421
# BK-SS      26.631579
# CC-OR     231.736842
# UC-UC      20.631579
# EN-BP      81.578947
# FV-FV      24.631579
# SO-LF      98.947368
# MB-CM      89.000000
#             ...
# EN-CN      30.789474
# HY-CV      20.578947
# SB-WP      53.000000
# UC-DC      52.105263
# NC-FM       8.789474
# NC-AS       7.315789
# FV-GP      64.263158
# SO-OA      18.263158
# CM-BP      75.842105
# HY-BP      24.526316
# FV-WC      40.842105
# SL-LM     273.000000
# OA-MB       4.947368
# WD-WD      14.684211
# PL-DC    1542.736842
# FM-WD      36.421053
# FM-OR      10.210526
# EP-WP      12.842105
# CC-CN     467.947368
# SS-WP      40.000000
# HY-CL     145.000000
# EN-WD      14.736842
# SH-CM       3.526316
# CL-EP      48.210526
# SS-OW      15.000000
# EP-RM      82.368421
# WS-BP       9.421053
# EM-CN     824.210526
# CV-SL      40.105263
# MB-OA       7.052632
# Name: dec2017, Length: 530, dtype: float64
